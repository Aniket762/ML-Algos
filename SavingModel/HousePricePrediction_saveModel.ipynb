# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn import linear_model

# %%
# %matplotlib inline

# %%
df = pd.read_csv("homeareas.csv")

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df.area,df.price)

# %%
plt.scatter(df.area,df.price,color="black",marker="+")

# %%
plt.scatter(df.area,df.price,color="red",marker="+")

# %%
plt.xlabel('area')
plt.ylabel('price(USD)')
# Out:
# Text(0, 0.5, 'price(USD)')

# %%
plt.xlabel('area')
plt.ylabel('price(USD)')
plt.scatter(df.area,df.price,color="red",marker="+")

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel('area')
plt.ylabel('price(USD)')
plt.scatter(df.area,df.price,color="red",marker="+")

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# array([628715.75342466])

# %%
reg.predict([[5500]])
# Out:
# array([927448.63013699])

# %%
import pickle

# %%
with open('model_pickle','wb') as f:
    pickle.dump(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-ad90d25258fd> in <module>
#       1 with open('model_pickle','wb') as f:
# ----> 2     pickle.dump(model)
#
# NameError: name 'model' is not defined
